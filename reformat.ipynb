# %%
import pandas as pd

# %%
df = pd.read_csv('profiles.csv')
df = df.replace('\n', ' ', regex=True)
df = df.rename(columns={"name": "Name", "email":"Email"}, errors="raise")
df = df.dropna(subset=['Email'])
df['Name'] = df['Name'].str.replace('"', "'")
df.to_csv('profiles_cleaned.csv', index=False)
display(df.info())
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41414 entries, 0 to 64125
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     41414 non-null  object
#  1   Email    41414 non-null  object
#  2   role     4 non-null      object
#  3   address  41414 non-null  object
#  4   url      41414 non-null  object
# dtypes: object(5)
# memory usage: 1.9+ MB
# None
#                              Name                                   Email  \
# 0                   GABAR Reports            gasbreports@cloudlawyers.com
# 2            Mr. Bruce Z. Walker                      bwalker@cpmtlaw.com
# 3         Mr. Stuart Coleman Cox                    stuart@ch13elpaso.com
# 4           Mr. Gary L. Seacrest                     glseacrest@gmail.com
# 5         Ms. Stephanie J. Cross                    scross@co.henry.ga.us
# ...                           ...                                     ...
# ...

# %%
#split csv into chunks of 970 rows to be uploaded into sendy
chunk_size = 5000

# read the CSV file into a pandas dataframe
df = pd.read_csv('profiles_cleaned.csv')

# split the dataframe into chunks of 970 rows
chunks = [df[i:i+chunk_size] for i in range(0, len(df), chunk_size)]

# save each chunk to a separate CSV file
for i, chunk in enumerate(chunks):
    chunk.to_csv(f'./georgia_contacts/Idaho_Bar_Association_chunk_{i}.csv', index=False)
